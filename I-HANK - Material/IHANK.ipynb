# %% [markdown]
# # A two-sector I-HANK model

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Setup](#toc1_)
# - 2. [Steady state](#toc2_)
# - 3. [Compute Jacobians](#toc3_)
# - 4. [Foreign demand shock](#toc4_)
# - 5. [Response in consumption to different shocks](#toc5_)
# - 6. [Decomposing consumption response](#toc6_)
# - 7. [Fixed vs floating exchange rate](#toc7_)
# - 8. [Decomposing consumption response under fixed exchange rate](#toc8_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import os #save figures
folder_material = "material extension"
os.makedirs(folder_material, exist_ok=True)


import matplotlib.pyplot as plt   
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams.update({"axes.grid" : True, "grid.color": "black", "grid.alpha":"0.25", "grid.linestyle": "--"})
plt.rcParams.update({'font.size': 14})

from IHANKModel import IHANKModelClass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Setup](#toc0_)

# %%
model = IHANKModelClass(name='baseline')

# %%
model.info()
# Out:
# settings:
#  par.py_hh = False
#  par.py_blocks = False
#  par.full_z_trans = False
#  par.warnings = True
#  par.T = 500
#
# households:
#  grids_hh: [a]
#  pols_hh: [a]
#  inputs_hh: [beta,ra,inc_TH,inc_NT]
#  inputs_hh_z: []
#  outputs_hh: [a,c,uc_TH,uc_NT,c_TH,c_NT]
#  intertemps_hh: [vbeg_a]
#
# aggregate:
#  shocks: [ZTH,ZNT,beta,G,i_shock,i_shock_eu,Z_eu,i_shock_us,Z_us]
#  unknowns: [CB,NNT,NTH,piWTH,piWNT,CB_us,C_eu,N_eu,pi_eu,i_eu,M_eu,C_us,N_us,pi_us,i_us,M_us,I_TH]
#  targets: [NKWCT_res,NKWCNT_res,clearing_YTH,clearing_YNT,eu_Euler_res,eu_NKPC_res,eu_TR_res,eu_LS_res,eu_RC_res,UIP_res,us_Euler_res,us_NKPC_res,us_TR_res,us_LS_res,us_RC_res,UIP_res_us,FOC_I_TH_res,FOC_I_eu_res,FOC_I_us_res]
#
# blocks (inputs -> outputs):
#  mon_pol: [CB,CB_us] -> [E,E_us]
#  materials_prices: [pi_eu,pi_us,E,E_us] -> [PF_eu_s,PF_us_s,PM_eu,PM_us,PM,PM_eu_eu,PM_eu_us,PM_eu_bundle,PM_us_eu,PM_us_us,PM_us_bundle]
#  eu_nk: [Z_eu,i_shock_eu,C_eu,N_eu,pi_eu,i_eu,M_eu,PF_eu_s,PM_eu_bundle] -> [rF_eu,M_eu_s,W_eu,Y_eu,mc_eu,eu_Euler_res,eu_LS_res,eu_NKPC_res,eu_TR_res,eu_RC_res,FOC_I_eu_res]
#  us_nk: [Z_us,i_shock_us,C_us,N_us,pi_us,i_us,M_us,PF_us_s,PM_us_bundle] -> [rF_us,M_us_s,W_us,Y_us,mc_us,us_Euler_res,us_LS_res,us_NKPC_res,us_TR_res,us_RC_res,FOC_I_us_res]
#  production: [ZTH,ZNT,NTH,NNT,I_TH,PM,piWTH,piWNT] -> [YTH,YNT,WTH,WNT,PTH,PNT,MC_TH]
#  FOC_I_TH: [NTH,I_TH,WTH,PM] -> [FOC_I_TH_res]
#  prices: [PF_eu_s,PF_us_s,E,E_us,PTH,PNT,WTH,WNT] -> [PF_eu,PF_us,PF_TF,PTH_eu_s,PTH_us_s,PT,P,Q,Q_us,wTH,wNT]
#  inflation: [PF_eu_s,PF_us_s,PF_eu,PF_us,PF_TF,PNT,PTH,PT,P,PTH_eu_s,PTH_us_s] -> [pi_F_eu_s,pi_F_us_s,pi_F_eu,pi_F_us,pi_FF,pi_NT,pi_TH,pi_T,pi,pi_TH_eu_s,pi_TH_us_s]
#  central_bank: [pi,E,i_shock,CB] -> [i,r,ra]
#  government: [PNT,P,wTH,NTH,wNT,NNT,ra,G] -> [B,tau,inc_TH,inc_NT]
#  hh: [beta,inc_NT,inc_TH,ra] -> [A_hh,C_hh,UC_TH_hh,UC_NT_hh,C_TH_hh,C_NT_hh]
#  NKWCs: [beta,piWTH,piWNT,NTH,NNT,wTH,wNT,tau,UC_TH_hh,UC_NT_hh] -> [NKWCT_res,NKWCNT_res]
#  UIP: [Q,r,rF_eu,Q_us,rF_us] -> [UIP_res,UIP_res_us]
#  consumption: [C_hh,PT,PNT,P,PTH,PF_TF,PF_eu,PF_us,M_eu_s,M_us_s,PTH_eu_s,PTH_us_s,PF_eu_s,PF_us_s] -> [CT,CNT,CTF,CTF_eu,CTF_us,CTH,CTH_eu_s,CTH_us_s]
#  market_clearing: [YTH,CTH,CTH_eu_s,CTH_us_s,YNT,CNT,G] -> [clearing_YTH,clearing_YNT]
#  accounting: [PTH,YTH,PNT,YNT,P,C_hh,G,A_hh,B,ra] -> [GDP,NX,CA,NFA,Walras]

# %%
model.draw_DAG(figsize=(15,15),order=['shocks','unknowns','blocks'])

# %%
par = model.par
ss = model.ss
path = model.path
sim = model.sim

# %% [markdown]
# ## 2. <a id='toc2_'></a>[Steady state](#toc0_)

# %%
model.find_ss(do_print=True)
# Out:
# household problem in ss solved in 7.3 secs [375 iterations]
# household problem in ss simulated in 4.7 secs [419 iterations]
# steady state found in 12.0 secs
# ss.inc_TH = 0.175
# ss.inc_NT = 0.525
# par.alphaT = 0.355
# par.alphaF = 0.333
# par.varphiTH = 1.271
# par.varphiNT = 1.271
# ss.M_eu_s = 0.022
# ss.M_us_s = 0.022
# ss.clearing_YTH =   0.00000000
# ss.clearing_YNT =   0.00000000
# ss.G = 0.296
# ss.NFA = 0.000
# ss.CB = 1.000
# ss.CB_us = 1.000

# %%
model.test_ss()
# Out:
# E              :       1.0000
# CB             :       1.0000
# E_us           :       1.0000
# CB_us          :       1.0000
# pi_eu          :       0.0000
# pi_us          :       0.0000
# PF_eu_s        :       1.0000
# PF_us_s        :       1.0000
# PM_eu          :       1.0000
# PM_us          :       1.0000
# PM             :       1.0000
# PM_eu_eu       :       1.0000
# PM_eu_us       :       1.0000
# PM_eu_bundle   :       1.0000
# PM_us_eu       :       1.0000
# PM_us_us       :       1.0000
# PM_us_bundle   :       1.0000
# Z_eu           :       1.0000
# i_shock_eu     :       0.0000
# C_eu           :       1.0000
# N_eu           :       1.0000
# i_eu           :       0.0050
# M_eu           :       0.6667
# rF_eu          :       0.0050
# M_eu_s         :       0.0215
# W_eu           :       1.0000
# Y_eu           :       0.8390
# mc_eu          :       1.0000
# eu_Euler_res   :       0.0000
# eu_LS_res      :       0.0000
# eu_NKPC_res    :       0.0000
# eu_TR_res      :       0.0000
# eu_RC_res      :       0.0000
# FOC_I_eu_res   :       0.0000
# Z_us           :       1.0000
# i_shock_us     :       0.0000
# C_us           :       1.0000
# N_us           :       1.0000
# i_us           :       0.0050
# M_us           :       0.6667
# rF_us          :       0.0050
# M_us_s         :       0.0215
# W_us           :       1.0000
# Y_us           :       0.8390
# mc_us          :       1.0000
# us_Euler_res   :       0.0000
# us_LS_res      :       0.0000
# us_NKPC_res    :       0.0000
# us_TR_res      :       0.0000
# us_RC_res      :       0.0000
# FOC_I_us_res   :       0.0000
# ZTH            :       1.0000
# ZNT            :       1.0000
# NTH            :       0.2500
# NNT            :       0.7500
# I_TH           :       0.1667
# piWTH          :       0.0000
# piWNT          :       0.0000
# YTH            :       0.2098
# YNT            :       0.7500
# WTH            :       1.0000
# WNT            :       1.0000
# PTH            :       1.0000
# PNT            :       1.0000
# MC_TH          :       1.0000
# FOC_I_TH_res   :       0.0000
# PF_eu          :       1.0000
# PF_us          :       1.0000
# PF_TF          :       1.0000
# PTH_eu_s       :       1.0000
# PTH_us_s       :       1.0000
# PT             :       1.0000
# P              :       1.0000
# Q              :       1.0000
# Q_us           :       1.0000
# wTH            :       1.0000
# wNT            :       1.0000
# pi_F_eu_s      :       0.0000
# pi_F_us_s      :       0.0000
# pi_F_eu        :       0.0000
# pi_F_us        :       0.0000
# pi_FF          :       0.0000
# pi_NT          :       0.0000
# pi_TH          :       0.0000
# pi_T           :       0.0000
# pi             :       0.0000
# pi_TH_eu_s     :       0.0000
# pi_TH_us_s     :       0.0000
# i              :       0.0050
# r              :       0.0050
# ra             :       0.0050
# i_shock        :       0.0000
# G              :       0.2963
# B              :       0.7483
# tau            :       0.3000
# inc_TH         :       0.1750
# inc_NT         :       0.5250
# beta           :       0.9750
# A_hh           :       0.7483
# C_hh           :       0.7037
# UC_TH_hh       :       2.1797
# UC_NT_hh       :       2.1797
# C_TH_hh        :       0.7037
# C_NT_hh        :       0.7037
# NKWCT_res      :       0.0000
# NKWCNT_res     :       0.0000
# UIP_res        :       0.0000
# UIP_res_us     :       0.0000
# CT             :       0.2500
# CNT            :       0.4537
# CTF            :       0.0833
# CTF_eu         :       0.0417
# CTF_us         :       0.0417
# CTH            :       0.1667
# CTH_eu_s       :       0.0215
# CTH_us_s       :       0.0215
# clearing_YTH   :       0.0000
# clearing_YNT   :       0.0000
# GDP            :       0.9598
# NX             :      -0.0402
# CA             :      -0.0402
# NFA            :       0.0000
# Walras         :      -0.0402

# %%
MPC = np.sum(ss.D[:,:,:-1]*(ss.c[:,:,1:]-ss.c[:,:,:-1])/((1+ss.r)*(par.a_grid[1:]-par.a_grid[:-1])))
print(f'{MPC:.2f}')
# Out:
# 0.32

# %%
fig = plt.figure(figsize=(18,4),dpi=100)
a_max = 10

# a. consumption
I = par.a_grid < a_max

ax = fig.add_subplot(1,3,1)
ax.set_title(f'consumption')

for i_z in [0,par.Nz//2,par.Nz-1]:
    ax.plot(par.a_grid[I],ss.c[0,i_z,I],label=f'i_z = {i_z}')

ax.legend(frameon=True)
ax.set_xlabel('savings, $a_{t-1}$')
ax.set_ylabel('consumption, $c_t$')

# b. saving
I = par.a_grid < a_max

ax = fig.add_subplot(1,3,2)
ax.set_title(f'saving')

for i_z in [0,par.Nz//2,par.Nz-1]:
    ax.plot(par.a_grid[I],ss.a[0,i_z,I],label=f'i_z = {i_z}')

ax.set_xlabel('savings, $a_{t-1}$')
ax.set_ylabel('savings, $a_{t}$')

fig.tight_layout()
#Saving figure
plt.title("cons_saving.png")
plt.savefig(os.path.join(folder_material, "cons_saving.png"), dpi=300, bbox_inches="tight")

# %%
fig = plt.figure(figsize=(12,4),dpi=100)

# a. income
ax = fig.add_subplot(1,2,1)
ax.set_title('productivity')

y = np.cumsum(np.sum(ss.D[0],axis=1))
ax.plot(par.z_grid,y/y[-1])

ax.set_xlabel('productivity, $z_{t}$')
ax.set_ylabel('CDF')

# b. assets
ax = fig.add_subplot(1,2,2)
ax.set_title('savings')
y = np.insert(np.cumsum(np.sum(ss.D[0],axis=0)),0,0.0)
ax.plot(np.insert(par.a_grid,0,par.a_grid[0]),y/y[-1])
        
ax.set_xlabel('assets, $a_{t}$')
ax.set_ylabel('CDF')
ax.set_xscale('symlog')
#Saving figure
plt.title("prod_saving.png")
plt.savefig(os.path.join(folder_material, "prod_saving.png"), dpi=300, bbox_inches="tight")

# %% [markdown]
# ## 3. <a id='toc3_'></a>[Compute Jacobians](#toc0_)

# %% [markdown]
# **Household transition path:**

# %%
model.test_hh_path()
#Saving figure
plt.title("test_hh_path.png")
plt.savefig(os.path.join(folder_material, "test_hh_path.png"), dpi=300, bbox_inches="tight")
# Out:
# note: inputs = steady state value -> expected: constant value (straigt line) in roughly -10^-5 to 10^5
#
# household problem solved along transition path in 1.9 secs
# household problem simulated along transition in 9.6 secs

# %% [markdown]
# **Full transition path:**

# %%
model.test_path()
# Out:
# shocks: ZTH ZNT beta G i_shock i_shock_eu Z_eu i_shock_us Z_us
# unknowns: CB NNT NTH piWTH piWNT CB_us C_eu N_eu pi_eu i_eu M_eu C_us N_us pi_us i_us M_us I_TH
#
# look at max(abs(path.VARNAME[:]-ss.VARNAME)):
#
#  blocks.mon_pol
#   E                0.0e+00
#   E_us             0.0e+00
#  blocks.materials_prices
#   PF_eu_s          0.0e+00
#   PF_us_s          0.0e+00
#   PM_eu            0.0e+00
#   PM_us            0.0e+00
#   PM               0.0e+00
#   PM_eu_eu         0.0e+00
#   PM_eu_us         0.0e+00
#   PM_eu_bundle     0.0e+00
#   PM_us_eu         0.0e+00
#   PM_us_us         0.0e+00
#   PM_us_bundle     0.0e+00
#  blocks.eu_nk
#   rF_eu            1.1e-16
#   M_eu_s           0.0e+00
#   W_eu             0.0e+00
#   Y_eu             0.0e+00
#   mc_eu            0.0e+00
#   eu_Euler_res     0.0e+00 [target]
#   eu_LS_res        0.0e+00 [target]
#   eu_NKPC_res      0.0e+00 [target]
#   eu_TR_res        0.0e+00 [target]
#   eu_RC_res        1.6e-01 [target]
#   FOC_I_eu_res     0.0e+00 [target]
#  blocks.us_nk
#   rF_us            1.1e-16
#   M_us_s           0.0e+00
#   W_us             0.0e+00
#   Y_us             0.0e+00
#   mc_us            0.0e+00
#   us_Euler_res     0.0e+00 [target]
#   us_LS_res        0.0e+00 [target]
#   us_NKPC_res      0.0e+00 [target]
#   us_TR_res        0.0e+00 [target]
#   us_RC_res        1.6e-01 [target]
#   FOC_I_us_res     0.0e+00 [target]
#  blocks.production
#   YTH              0.0e+00
#   YNT              0.0e+00
#   WTH              0.0e+00
#   WNT              0.0e+00
#   PTH              0.0e+00
#   PNT              0.0e+00
#   MC_TH            0.0e+00
#  blocks.FOC_I_TH
#   FOC_I_TH_res     0.0e+00 [target]
#  blocks.prices
#   PF_eu            0.0e+00
#   PF_us            0.0e+00
#   PF_TF            0.0e+00
#   PTH_eu_s         0.0e+00
#   PTH_us_s         0.0e+00
#   PT               0.0e+00
#   P                0.0e+00
#   Q                0.0e+00
#   Q_us             0.0e+00
#   wTH              0.0e+00
#   wNT              0.0e+00
#  blocks.inflation
#   pi_F_eu_s        0.0e+00
#   pi_F_us_s        0.0e+00
#   pi_F_eu          0.0e+00
#   pi_F_us          0.0e+00
#   pi_FF            0.0e+00
#   pi_NT            0.0e+00
#   pi_TH            0.0e+00
#   pi_T             0.0e+00
#   pi               0.0e+00
#   pi_TH_eu_s       0.0e+00
#   pi_TH_us_s       0.0e+00
#  blocks.central_bank
#   i                1.1e-16
#   r                1.1e-16
#   ra               1.1e-16
#  blocks.government
#   B                5.6e-16
#   tau              5.6e-17
#   inc_TH           2.8e-17
#   inc_NT           1.1e-16
#  hh
#   A_hh             2.5e-10
#   C_hh             1.5e-11
#   UC_TH_hh         7.8e-11
#   UC_NT_hh         7.8e-11
#   C_TH_hh          1.5e-11
#   C_NT_hh          1.5e-11
#  blocks.NKWCs
#   NKWCT_res        4.6e-12 [target]
#   NKWCNT_res       4.6e-12 [target]
#  blocks.UIP
#   UIP_res          0.0e+00 [target]
#   UIP_res_us       0.0e+00 [target]
#  blocks.consumption
#   CT               5.2e-12
#   CNT              9.5e-12
#   CTF              1.7e-12
#   CTF_eu           8.7e-13
#   CTF_us           8.7e-13
#   CTH              3.5e-12
#   CTH_eu_s         0.0e+00
#   CTH_us_s         0.0e+00
#  blocks.market_clearing
#   clearing_YTH     3.5e-12 [target]
#   clearing_YNT     9.5e-12 [target]
#  blocks.accounting
#   GDP              0.0e+00
#   NX               1.5e-11
#   CA               1.3e-11
#   NFA              2.5e-10
#   Walras           8.0e-02

# %% [markdown]
# **Jacobians:**

# %%
model.compute_jacs(do_print=True)
# Out:
# household Jacobians:
# one step deviation from steady state calculated in 0.0 secs
# curly_Y and curly_D calculated for beta            in 1.4 secs
# curly_Y and curly_D calculated for inc_NT          in 1.2 secs
# curly_Y and curly_D calculated for inc_TH          in 1.2 secs
# curly_Y and curly_D calculated for ra              in 1.2 secs
# curly_E calculated in 0.7 secs
# builiding blocks combined in 1.5 secs
# household Jacobian computed in 7.2 secs
#
# full Jacobians:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 model.compute_jacs(do_print=True)
#
# File c:\users\kons-lk\desktop\master-thesis\gemodeltools\GEModelTools\GEModelClass.py:1388, in GEModelClass.compute_jacs(self, dx, skip_hh, inputs_hh_all, skip_shocks, do_print, do_direct)
#    1385     if do_print: print('')
#    1387 if do_print: print('full Jacobians:')
# -> 1388 self._compute_jac(inputs='unknowns',dx=dx,do_print=do_print)
#    1389 if not skip_shocks: self._compute_jac(inputs='shocks',dx=dx,do_print=do_print)
#
# File c:\users\kons-lk\desktop\master-thesis\gemodeltools\GEModelTools\GEModelClass.py:1342, in GEModelClass._compute_jac(self, inputs, dx, do_print)
#    1340 self._set_unknowns(x0,inputs)
#    1341 t0_ = time.time()
# -> 1342 self.evaluate_blocks(ncols=len(inputs)*par.T,use_jac_hh=True)
#    1343 evaluate_t += time.time()-t0_
#    1344 errors = self._get_errors(inputs)
#
# File c:\users\kons-lk\desktop\master-thesis\gemodeltools\GEModelTools\GEModelClass.py:1638, in GEModelClass.evaluate_blocks(self, ini, ncols, use_jac_hh)
#    1635 else:
#    1637     varnames = get_varnames(blockstr)
# -> 1638     self.call_block(blockstr)
#    1640 if par.warnings:
#    1642     for varname in varnames:
#
# File c:\users\kons-lk\desktop\master-thesis\gemodeltools\GEModelTools\GEModelClass.py:509, in GEModelClass.call_block(self, blockstr)
#     506 func = eval(f'module.{funcname}')
#     508 # c. call
# --> 509 with jit(self,show_exc=False) as model:
#     510     if self.par.py_blocks:
#     511         if hasattr(func,'py_func'):
#
# File c:\Anaconda3\Lib\site-packages\EconModel\jit.py:31, in jit.__exit__(self, exc_type, exc_value, tb)
#      27         setattr(model,ns,jit)
#      29     return model
# ---> 31 def __exit__(self, exc_type, exc_value, tb):
#      32     """ swap back to normal namespaces and delete jitted namespaces """
#      34     if exc_type is not None and self.show_exc:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. <a id='toc4_'></a>[Foreign demand shock](#toc0_)

# %%
#par.jump_M_eu_s = -0.0075 # initial jump
#par.rho_M_eu_s = 0.80 # AR(1) coefficeint

#par.jump_rn_eu = -0.00005 # initial jump
#par.rho_rn_eu = 0.80 # AR(1) coefficeint

par.jump_i_shock_eu = -0.03 # initial jump
par.rho_i_shock_eu= 0.80 # AR(1) coefficeint

par.jump_i_shock = -0.03 # initial jump
par.rho_i_shock= 0.80 # AR(1) coefficeint

model.find_transition_path(shocks=['i_shock_eu', 'i_shock'],do_print=True,do_end_check=False)

print("max |i_shock_eu|:", np.max(np.abs(model.path.i_shock_eu)))
print("max |i_shock|   :", np.max(np.abs(model.path.i_shock)))

# %%
paths = ['GDP','YTH','YNT','C_hh','C_TH_hh','C_NT_hh','CT','CTH','CTF','CNT','CTH_eu_s','ra','inc_TH','inc_NT','tau','Q','E','NFA','Walras']
lvl_value=['r','NFA','Walras','i_shock', 'i_shock_eu', 'i_shock_us']
model.show_IRFs(paths,lvl_value=lvl_value,T_max=48,ncols=3, filename=os.path.join(folder_material, "i_shock_ishock_eu"))

# %%
model.show_IRFs(['NFA','Q','E', 'E_us'],lvl_value=lvl_value,T_max=500,ncols=3,do_shocks=False,do_targets=False)

# %% [markdown]
# ## 5. <a id='toc5_'></a>[Response in consumption to different shocks](#toc0_)

# %% [markdown]
# EU i shock:

# %%
M_s = model.copy()
M_s.par.jump_i_shock_eu = -0.01 # initial jump
M_s.par.rho_i_shock_eu= 0.80 # AR(1) coefficeint

M_s.find_transition_path(shocks=['i_shock_eu'],do_print=False,do_end_check=False)

# %% [markdown]
# Domestic Beta shock:

# %%
beta = model.copy()
beta.par.jump_beta = 0.01 # initial jump
beta.par.rho_beta = 0.80 # AR(1) coefficeint

beta.find_transition_path(shocks=['beta'],do_print=False,do_end_check=False)

# %% [markdown]
# Domestic G shock:

# %%
G = model.copy()
G.par.jump_G = -0.025 # initial jump
G.par.rho_G = 0.80 # AR(1) coefficeint

G.find_transition_path(shocks=['G'],do_print=False,do_end_check=False)

# %% [markdown]
# Domestic i shock:

# %%
i_shock_model = model.copy()
i_shock_model.par.jump_i_shock = -0.01 # initial jump
i_shock_model.par.rho_i_shock= 0.80 # AR(1) coefficeint

i_shock_model.find_transition_path(shocks=['i_shock'],do_print=False,do_end_check=False)

# %% [markdown]
# US i shock:

# %%
i_shock_us_model = model.copy()
i_shock_us_model.par.jump_i_shock_us = -0.01 # initial jump
i_shock_us_model.par.rho_i_shock_us= 0.80 # AR(1) coefficeint

i_shock_us_model.find_transition_path(shocks=['i_shock_us'],do_print=False,do_end_check=False)

# %%
models = [M_s,i_shock_model,i_shock_us_model]
labels = ['i_shock_eu','i_shock', 'i_shock_us']
model.compare_IRFs(models,labels,varnames=['M_eu_s','M_us_s','beta','G','i_shock', 'i_shock_eu', 'i_shock_us','C_hh','C_TH_hh','C_NT_hh','CT','CTH','CTF','CTF_eu','CTF_us','CNT','CTH_eu_s','CTH_us_s'], do_shocks=False,do_targets=False,
        abs_diff=None,lvl_value=['i_shock', 'i_shock_eu', 'i_shock_us'],T_max=50, filename=os.path.join(folder_material, "compare_shocks"))

# %% [markdown]
# ## 6. <a id='toc6_'></a>[Decomposing consumption response](#toc0_)

# %%
models = {'i_shock_eu': M_s, 'beta': beta, 'G': G, 'i_shock': i_shock_model}

model_titles = {
    'i_shock_eu': 'Contractionary Foreign Monetary Shock',
    'beta': 'Domestic Beta Shock',
    'G': 'Contractionary Domestic Fiscal Shock',
    'i_shock': 'Contractionary Domestic Monetary Shock'
}

for model_name, model in models.items():

    T_max = 50

    fig, (ax_C_NT, ax_C_TH) = plt.subplots(1, 2, figsize=(16, 4), dpi=100)
    fig.suptitle(f'{model_titles[model_name]}', fontsize=16)

    ax_C_NT.set_title('Consumption non-tradeable sector HH, $C_{NT}^{hh}$', fontsize=12)
    ax_C_TH.set_title('Consumption tradeable sector HH, $C_{TH}^{hh}$', fontsize=12)

    i_color = 0

    for use_inputs in [[x] for x in model.inputs_hh]:

        # a. compute
        path_alt = model.decompose_hh_path(do_print=False, use_inputs=use_inputs)

        # b. plot
        if use_inputs is None:
            label = 'No inputs'
            ls = '--'
            color = 'black'
        elif use_inputs == 'all':
            label = 'All inputs'
            ls = '-'
            color = 'black'
        else:
            label = f'Only effect from {use_inputs[0]}'
            ls = '-'
            color = f'C{i_color}' # use color index directly
            i_color += 1

        ax_C_NT.plot((path_alt.C_NT_hh[:T_max] / ss.C_NT_hh - 1) * 100, ls=ls, color=color, label=label)
        ax_C_TH.plot((path_alt.C_TH_hh[:T_max] / ss.C_TH_hh - 1) * 100, ls=ls, color=color, label=label)

    for ax in [ax_C_NT, ax_C_TH]:
        ax.set_ylabel('% diff to s.s.')
        lgd = ax_C_TH.legend(frameon=True, ncol=1, bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

    plt.tight_layout()  # Adjust layout to prevent overlapping
    plt.show()

# %% [markdown]
# ## 7. <a id='toc7_'></a>[Fixed vs floating exchange rate](#toc0_)

# %%
fixed = model.copy()
fixed.par.float = False
fixed.find_ss()
fixed.compute_jacs()

# %% [markdown]
# Foreign demand shock:

# %%
M_s_fixed = fixed.copy()
M_s_fixed.par.jump_i_shock_eu = -0.01 # initial jump
M_s_fixed.par.rho_i_shock_eu= 0.80 # AR(1) coefficeint

M_s_fixed.find_transition_path(shocks=['i_shock_eu'])

# %%
i_shock_us_fixed = fixed.copy()
i_shock_us_fixed.par.jump_i_shock_us = -0.01 # initial jump
i_shock_us_fixed.par.rho_i_shock_us= 0.80 # AR(1) coefficeint

i_shock_us_fixed.find_transition_path(shocks=['i_shock_us'],do_print=False,do_end_check=False)

# %%
models = [M_s,M_s_fixed,i_shock_us_model,i_shock_us_fixed]
labels = ['floating - i_eu','fixed - i_eu','floating - i_us','fixed - i_us']
model.compare_IRFs(models,labels,varnames=['M_eu_s','M_us_s','beta','G','i_shock', 'i_shock_eu', 'i_shock_us','C_hh','C_TH_hh','C_NT_hh','CT','CTH','CTF','CTF_eu','CTF_us','CNT','CTH_eu_s','CTH_us_s'], do_shocks=False,do_targets=False,
        abs_diff=None,lvl_value=['i_shock','pi', 'i_shock_eu','i', 'i_shock_us'],T_max=50, filename=os.path.join(folder_material, "fixed_float"))

# %% [markdown]
# Domestic beta shock:

# %%
beta_fixed = fixed.copy()
beta_fixed.par.jump_beta = 0.01 # initial jump
beta_fixed.par.rho_beta = 0.80 # AR(1) coefficeint

beta_fixed.find_transition_path(shocks=['beta'])

# %%
models = [beta,beta_fixed]
labels = ['floating','fixed']
model.compare_IRFs(models,labels,varnames=['beta','C_hh','C_TH_hh','C_NT_hh','CT','CTH','CTF','CNT','CTH_eu_s','i','E'], do_shocks=False,do_targets=False,
        abs_diff=None,lvl_value=['i_shock'],T_max=50)

# %% [markdown]
# Domestic G shock:

# %%
G_fixed = fixed.copy()
G_fixed.par.jump_G = -0.025 # initial jump
G_fixed.par.rho_G = 0.80 # AR(1) coefficeint

G_fixed.find_transition_path(shocks=['G'])

# %%
models = [G,G_fixed]
labels = ['floating','fixed']
model.compare_IRFs(models,labels,varnames=['G','C_hh','C_TH_hh','C_NT_hh','CT','CTH','CTF','CNT','CTH_eu_s','i','E'], do_shocks=False,do_targets=False,
        abs_diff=None,lvl_value=['i_shock'],T_max=50)

# %% [markdown]
# ## 8. <a id='toc8_'></a>[Decomposing consumption response under fixed exchange rate](#toc0_)

# %%
models = {'M_s': M_s_fixed, 'beta': beta_fixed, 'G': G_fixed}

model_titles = {
    'M_s': 'Foreign Demand Shock',
    'beta': 'Domestic Beta Shock',
    'G': 'Contractionary Domestic Fiscal Shock'   
}

for model_name, model in models.items():

    T_max = 50

    fig, (ax_C_NT, ax_C_TH) = plt.subplots(1, 2, figsize=(16, 4), dpi=100)
    fig.suptitle(f'{model_titles[model_name]}', fontsize=16)

    ax_C_NT.set_title('Consumption non-tradeable sector HH, $C_{NT}^{hh}$', fontsize=12)
    ax_C_TH.set_title('Consumption tradeable sector HH, $C_{TH}^{hh}$', fontsize=12)

    i_color = 0

    for use_inputs in [[x] for x in model.inputs_hh]:

        # a. compute
        path_alt = model.decompose_hh_path(do_print=False, use_inputs=use_inputs)

        # b. plot
        if use_inputs is None:
            label = 'No inputs'
            ls = '--'
            color = 'black'
        elif use_inputs == 'all':
            label = 'All inputs'
            ls = '-'
            color = 'black'
        else:
            label = f'Only effect from {use_inputs[0]}'
            ls = '-'
            color = f'C{i_color}' # use color index directly
            i_color += 1

        ax_C_NT.plot((path_alt.C_NT_hh[:T_max] / ss.C_NT_hh - 1) * 100, ls=ls, color=color, label=label)
        ax_C_TH.plot((path_alt.C_TH_hh[:T_max] / ss.C_TH_hh - 1) * 100, ls=ls, color=color, label=label)

    for ax in [ax_C_NT, ax_C_TH]:
        ax.set_ylabel('% diff to s.s.')
        lgd = ax_C_TH.legend(frameon=True, ncol=1, bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

    plt.tight_layout()  # Adjust layout to prevent overlapping
    plt.show()
